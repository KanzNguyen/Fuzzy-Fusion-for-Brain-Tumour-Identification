# %%
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay, f1_score
import joblib
import torch
import torch.nn as nn
from torchvision.transforms import Resize, ToTensor, Compose, Normalize, transforms

from tqdm import tqdm
from torchvision import transforms
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC
from os import listdir
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from keras.layers import Reshape
from keras.layers import Input, Dense, concatenate
from keras.models import Model
from collections import defaultdict
from xgboost import XGBClassifier
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from torchvision.models import mobilenet_v3_large
from sklearn.metrics import precision_score, recall_score
import seaborn as sns
import tensorflow as tf
# Out:
# 2026-03-03 17:09:35.362496: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772557775.663917      18 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772557775.757173      18 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772557776.479747      18 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772557776.479799      18 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772557776.479802      18 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772557776.479805      18 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
data = pd.read_csv("/kaggle/input/datasets/sealeopard/brain-tumor-csv/Brain Tumor.csv")
data.head()
# Out:
#     Image  Class      Mean     Variance  Standard Deviation   Entropy  \
# 0  Image1      0  6.535339   619.587845           24.891522  0.109059
# 1  Image2      0  8.749969   805.957634           28.389393  0.266538
# 2  Image3      1  7.341095  1143.808219           33.820234  0.001467
# 3  Image4      1  5.958145   959.711985           30.979219  0.001477
# 4  Image5      0  7.315231   729.540579           27.010009  0.146761
#
#    Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 0  4.276477  18.900575   98.613971  0.293314  0.086033     0.530941
# 1  3.718116  14.464618   63.858816  0.475051  0.225674     0.651352
# 2  5.061750  26.479563   81.867206  0.031917  0.001019     0.268275
# 3  5.677977  33.428845  151.229741  0.032024  0.001026     0.243851
# 4  4.283221  19.079108  174.988756  0.343849  0.118232     0.501140
#
#    Dissimilarity  Correlation     Coarseness
# 0       4.473346     0.981939  7.458341e-155
# 1       3.220072     0.988834  7.458341e-155
# 2       5.981800     0.978014  7.458341e-155
# 3       7.700919     0.964189  7.458341e-155
# 4       6.834689     0.972789  7.458341e-155

# %%
images = data.Image
classes = data.Class
image_label_dict = data.set_index('Image')['Class'].to_dict()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
def preprocess_image(image_path):
  image = Image.open(image_path).convert('RGB')
  transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
      #transforms.Normalize(mean=[0.5], std=[0.5])
  ])
  image = transform(image)
  image = image.unsqueeze(0)
  return image.to(device)
def extract_features(image, model):
  with torch.no_grad():
    feature = model(image).squeeze().cpu().numpy()
  return feature
def extract_features_from_image(image_path, model):
  image = preprocess_image(image_path)
  features = extract_features(image, model)
  return features
def preprocess_image_pca(image_path):
    image = Image.open(image_path).convert('RGB') 
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])
    image = transform(image)
    image = image.numpy().flatten()
    return image

# %%
import torchvision.models as models

mobilenet_v3_large_model = models.mobilenet_v3_large(pretrained=True) 
mobilenet_v3_large_model = nn.Sequential(*list(mobilenet_v3_large_model.children())[:-1])  
mobilenet_v3_large_model = mobilenet_v3_large_model.to(device)
mobilenet_v3_large_model.eval()

dir_list = '/kaggle/input/datasets/sealeopard/reloaded-crop/Crop/'
X_mobilenet_v3_large = []
X_pca_orig = []
Y = []
filename_list = []

for filename in tqdm(listdir(dir_list)):
    if filename.endswith('.jpg'):
        filename_list.append(filename)
        path = dir_list + filename
        label = image_label_dict.get(filename.split('.')[0], None)
        
        if label is not None:
            features = extract_features_from_image(path, mobilenet_v3_large_model)
            features = features.flatten()  
            X_mobilenet_v3_large.append(features)
            feature_pca = preprocess_image_pca(path)
            X_pca_orig.append(feature_pca)
            Y.append(label)

X_resnet = np.array(X_mobilenet_v3_large)
X_pca_orig = np.array(X_pca_orig)
Y = np.array(Y)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 137MB/s]
# 100%|██████████| 3762/3762 [01:57<00:00, 32.05it/s]

# %%
print(X_resnet[0].shape)
print(X_pca_orig[0].shape)
# Out:
# (960,)
# (150528,)

# %%
n_components = 0.95
pca_model = PCA(n_components=n_components, random_state=42)
X_pca = pca_model.fit_transform(X_pca_orig)
print(X_pca[0].shape)
X_pca = np.hstack((X_resnet, X_pca))
print(X_pca[0].shape)
# Out:
# (378,)
# (1338,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, Y, test_size=0.5, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)
print(X_train.shape)
# Out:
# (1598, 1338)

# %%
def create_cnn_model(input_shape, num_filters):
  model = Sequential()
  model = Sequential()
  model.add(Reshape((input_shape[1], 1), input_shape=input_shape[1:]))
  model.add(Conv1D(filters=num_filters, kernel_size=3, activation='relu', input_shape=(500, 1)))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Conv1D(filters=num_filters * 2, kernel_size=3, activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())
  model.add(Dense(64, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model

model1 = create_cnn_model(X_train.shape, 32)
model2 = create_cnn_model(X_train.shape, 64)
model3 = create_cnn_model(X_train.shape, 48)

#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_val = scaler.transform(X_val)
#_test = scaler.transform(X_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')

y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

model1.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_val, y_val))
model2.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_val, y_val))
model3.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_val, y_val))

loss, accuracy = model1.evaluate(X_test, y_test)
print(f'Accuracy1: {accuracy*100:.2f}%')

loss, accuracy = model2.evaluate(X_test, y_test)
print(f'Accuracy2: {accuracy*100:.2f}%')

loss, accuracy = model3.evaluate(X_test, y_test)
print(f'Accuracy3: {accuracy*100:.2f}%')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-03-03 17:16:31.477183: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.6303 - loss: 0.8678 - val_accuracy: 0.9187 - val_loss: 0.2357
# Epoch 2/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9010 - loss: 0.2404 - val_accuracy: 0.9470 - val_loss: 0.1683
# Epoch 3/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9388 - loss: 0.1596 - val_accuracy: 0.9611 - val_loss: 0.1370
# Epoch 4/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9745 - loss: 0.0692 - val_accuracy: 0.9399 - val_loss: 0.1822
# Epoch 5/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9855 - loss: 0.0517 - val_accuracy: 0.9541 - val_loss: 0.1374
# Epoch 6/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9975 - loss: 0.0289 - val_accuracy: 0.9647 - val_loss: 0.1491
# Epoch 7/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9949 - loss: 0.0216 - val_accuracy: 0.9187 - val_loss: 0.2393
# Epoch 8/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9972 - loss: 0.0164 - val_accuracy: 0.9682 - val_loss: 0.1518
# Epoch 9/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9611 - val_loss: 0.1607
# Epoch 10/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9611 - val_loss: 0.1649
# Epoch 11/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9611 - val_loss: 0.1737
# Epoch 12/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9576 - val_loss: 0.1759
# Epoch 13/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9576 - val_loss: 0.1814
# Epoch 14/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9576 - val_loss: 0.1849
# Epoch 15/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 8.9063e-04 - val_accuracy: 0.9611 - val_loss: 0.1888
# Epoch 16/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 8.1504e-04 - val_accuracy: 0.9611 - val_loss: 0.1925
# Epoch 17/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 6.6606e-04 - val_accuracy: 0.9611 - val_loss: 0.1968
# Epoch 18/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 6.6163e-04 - val_accuracy: 0.9647 - val_loss: 0.2004
# Epoch 19/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 5.9336e-04 - val_accuracy: 0.9611 - val_loss: 0.2011
# Epoch 20/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 4.4418e-04 - val_accuracy: 0.9647 - val_loss: 0.2050
# Epoch 21/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 4.5288e-04 - val_accuracy: 0.9647 - val_loss: 0.2063
# Epoch 22/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 3.4932e-04 - val_accuracy: 0.9647 - val_loss: 0.2094
# Epoch 23/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 3.3810e-04 - val_accuracy: 0.9576 - val_loss: 0.2112
# Epoch 24/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 3.4693e-04 - val_accuracy: 0.9647 - val_loss: 0.2143
# Epoch 25/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 2.6549e-04 - val_accuracy: 0.9611 - val_loss: 0.2155
# Epoch 26/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 2.4896e-04 - val_accuracy: 0.9611 - val_loss: 0.2191
# Epoch 27/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 2.3605e-04 - val_accuracy: 0.9611 - val_loss: 0.2200
# Epoch 28/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 2.0103e-04 - val_accuracy: 0.9611 - val_loss: 0.2226
# Epoch 29/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 1.8235e-04 - val_accuracy: 0.9611 - val_loss: 0.2244
# Epoch 30/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.6753e-04 - val_accuracy: 0.9611 - val_loss: 0.2254
# Epoch 31/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.7371e-04 - val_accuracy: 0.9611 - val_loss: 0.2274
# Epoch 32/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 1.6160e-04 - val_accuracy: 0.9611 - val_loss: 0.2292
# Epoch 33/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.4097e-04 - val_accuracy: 0.9576 - val_loss: 0.2302
# Epoch 34/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 1.0000 - loss: 1.3607e-04 - val_accuracy: 0.9611 - val_loss: 0.2325
# Epoch 35/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.3699e-04 - val_accuracy: 0.9611 - val_loss: 0.2343
# Epoch 36/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 1.1167e-04 - val_accuracy: 0.9611 - val_loss: 0.2357
# Epoch 37/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.0233e-04 - val_accuracy: 0.9611 - val_loss: 0.2367
# Epoch 38/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 9.9539e-05 - val_accuracy: 0.9611 - val_loss: 0.2382
# Epoch 39/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 1.0149e-04 - val_accuracy: 0.9611 - val_loss: 0.2395
# Epoch 40/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 8.4970e-05 - val_accuracy: 0.9611 - val_loss: 0.2415
# Epoch 1/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.5822 - loss: 1.0557 - val_accuracy: 0.8799 - val_loss: 0.2765
# Epoch 2/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.8804 - loss: 0.2968 - val_accuracy: 0.9435 - val_loss: 0.1664
# Epoch 3/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9551 - loss: 0.1403 - val_accuracy: 0.9576 - val_loss: 0.1421
# Epoch 4/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9802 - loss: 0.0655 - val_accuracy: 0.9505 - val_loss: 0.1376
# Epoch 5/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9938 - loss: 0.0382 - val_accuracy: 0.9435 - val_loss: 0.2204
# Epoch 6/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9869 - loss: 0.0500 - val_accuracy: 0.9576 - val_loss: 0.1433
# Epoch 7/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9989 - loss: 0.0142 - val_accuracy: 0.9505 - val_loss: 0.1570
# Epoch 8/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9470 - val_loss: 0.1690
# Epoch 9/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9505 - val_loss: 0.1789
# Epoch 10/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9505 - val_loss: 0.1821
# Epoch 11/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9505 - val_loss: 0.1878
# Epoch 12/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9505 - val_loss: 0.1920
# Epoch 13/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 8.2693e-04 - val_accuracy: 0.9470 - val_loss: 0.1946
# Epoch 14/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 6.8633e-04 - val_accuracy: 0.9505 - val_loss: 0.1972
# Epoch 15/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 6.0569e-04 - val_accuracy: 0.9505 - val_loss: 0.2015
# Epoch 16/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 1.0000 - loss: 5.1408e-04 - val_accuracy: 0.9505 - val_loss: 0.2049
# Epoch 17/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 4.2613e-04 - val_accuracy: 0.9470 - val_loss: 0.2086
# Epoch 18/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 3.2375e-04 - val_accuracy: 0.9470 - val_loss: 0.2102
# Epoch 19/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 3.1590e-04 - val_accuracy: 0.9470 - val_loss: 0.2136
# Epoch 20/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 2.8648e-04 - val_accuracy: 0.9541 - val_loss: 0.2141
# Epoch 21/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 2.5515e-04 - val_accuracy: 0.9470 - val_loss: 0.2190
# Epoch 22/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 2.1624e-04 - val_accuracy: 0.9470 - val_loss: 0.2207
# Epoch 23/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 2.1043e-04 - val_accuracy: 0.9505 - val_loss: 0.2218
# Epoch 24/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 1.8676e-04 - val_accuracy: 0.9470 - val_loss: 0.2243
# Epoch 25/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 1.8508e-04 - val_accuracy: 0.9470 - val_loss: 0.2270
# Epoch 26/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 1.0000 - loss: 1.6738e-04 - val_accuracy: 0.9505 - val_loss: 0.2273
# Epoch 27/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 1.5100e-04 - val_accuracy: 0.9470 - val_loss: 0.2297
# Epoch 28/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 1.2700e-04 - val_accuracy: 0.9470 - val_loss: 0.2327
# Epoch 29/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 1.2634e-04 - val_accuracy: 0.9505 - val_loss: 0.2331
# Epoch 30/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 1.0000 - loss: 1.1024e-04 - val_accuracy: 0.9505 - val_loss: 0.2346
# Epoch 31/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 1.0000 - loss: 1.1280e-04 - val_accuracy: 0.9505 - val_loss: 0.2358
# Epoch 32/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 9.5219e-05 - val_accuracy: 0.9505 - val_loss: 0.2387
# Epoch 33/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 1.0000 - loss: 9.1202e-05 - val_accuracy: 0.9470 - val_loss: 0.2409
# Epoch 34/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 8.8945e-05 - val_accuracy: 0.9505 - val_loss: 0.2417
# Epoch 35/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 1.0000 - loss: 8.7379e-05 - val_accuracy: 0.9505 - val_loss: 0.2432
# Epoch 36/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 1.0000 - loss: 7.2159e-05 - val_accuracy: 0.9505 - val_loss: 0.2452
# Epoch 37/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 1.0000 - loss: 7.1016e-05 - val_accuracy: 0.9505 - val_loss: 0.2466
# Epoch 38/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 6.3012e-05 - val_accuracy: 0.9470 - val_loss: 0.2484
# Epoch 39/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 1.0000 - loss: 6.1109e-05 - val_accuracy: 0.9505 - val_loss: 0.2493
# Epoch 40/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 1.0000 - loss: 5.7434e-05 - val_accuracy: 0.9505 - val_loss: 0.2510
# Epoch 1/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.6955 - loss: 0.6906 - val_accuracy: 0.9152 - val_loss: 0.2068
# Epoch 2/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9100 - loss: 0.2212 - val_accuracy: 0.9293 - val_loss: 0.1907
# Epoch 3/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9703 - loss: 0.0986 - val_accuracy: 0.9576 - val_loss: 0.1413
# Epoch 4/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9875 - loss: 0.0577 - val_accuracy: 0.9541 - val_loss: 0.1183
# Epoch 5/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9963 - loss: 0.0251 - val_accuracy: 0.9576 - val_loss: 0.1246
# Epoch 6/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9974 - loss: 0.0144 - val_accuracy: 0.9576 - val_loss: 0.1199
# Epoch 7/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9541 - val_loss: 0.1316
# Epoch 8/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9985 - loss: 0.0076 - val_accuracy: 0.9611 - val_loss: 0.1460
# Epoch 9/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9682 - val_loss: 0.1427
# Epoch 10/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9682 - val_loss: 0.1486
# Epoch 11/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 9.8788e-04 - val_accuracy: 0.9682 - val_loss: 0.1533
# Epoch 12/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 7.9746e-04 - val_accuracy: 0.9682 - val_loss: 0.1536
# Epoch 13/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 6.1887e-04 - val_accuracy: 0.9682 - val_loss: 0.1571
# Epoch 14/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 5.5188e-04 - val_accuracy: 0.9682 - val_loss: 0.1607
# Epoch 15/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 4.5451e-04 - val_accuracy: 0.9682 - val_loss: 0.1626
# Epoch 16/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 4.5275e-04 - val_accuracy: 0.9682 - val_loss: 0.1629
# Epoch 17/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 3.6247e-04 - val_accuracy: 0.9717 - val_loss: 0.1673
# Epoch 18/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 3.1670e-04 - val_accuracy: 0.9682 - val_loss: 0.1669
# Epoch 19/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 1.0000 - loss: 2.7464e-04 - val_accuracy: 0.9682 - val_loss: 0.1685
# Epoch 20/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 2.5445e-04 - val_accuracy: 0.9682 - val_loss: 0.1709
# Epoch 21/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 2.0718e-04 - val_accuracy: 0.9717 - val_loss: 0.1741
# Epoch 22/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 2.1321e-04 - val_accuracy: 0.9682 - val_loss: 0.1731
# Epoch 23/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 1.9012e-04 - val_accuracy: 0.9717 - val_loss: 0.1751
# Epoch 24/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 1.4673e-04 - val_accuracy: 0.9682 - val_loss: 0.1769
# Epoch 25/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 1.5477e-04 - val_accuracy: 0.9682 - val_loss: 0.1755
# Epoch 26/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 1.4111e-04 - val_accuracy: 0.9682 - val_loss: 0.1782
# Epoch 27/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 1.2330e-04 - val_accuracy: 0.9682 - val_loss: 0.1797
# Epoch 28/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 1.2138e-04 - val_accuracy: 0.9682 - val_loss: 0.1797
# Epoch 29/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 1.0118e-04 - val_accuracy: 0.9717 - val_loss: 0.1827
# Epoch 30/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 9.8045e-05 - val_accuracy: 0.9717 - val_loss: 0.1838
# Epoch 31/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 9.4044e-05 - val_accuracy: 0.9717 - val_loss: 0.1856
# Epoch 32/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 9.3729e-05 - val_accuracy: 0.9682 - val_loss: 0.1827
# Epoch 33/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 8.0359e-05 - val_accuracy: 0.9682 - val_loss: 0.1841
# Epoch 34/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 8.1355e-05 - val_accuracy: 0.9682 - val_loss: 0.1852
# Epoch 35/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 1.0000 - loss: 6.9808e-05 - val_accuracy: 0.9682 - val_loss: 0.1858
# Epoch 36/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 7.6119e-05 - val_accuracy: 0.9717 - val_loss: 0.1885
# Epoch 37/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 5.7769e-05 - val_accuracy: 0.9717 - val_loss: 0.1886
# Epoch 38/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 5.5173e-05 - val_accuracy: 0.9682 - val_loss: 0.1870
# Epoch 39/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 5.2290e-05 - val_accuracy: 0.9682 - val_loss: 0.1888
# Epoch 40/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 5.2467e-05 - val_accuracy: 0.9682 - val_loss: 0.1892
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.2714
# Accuracy1: 95.53%
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9540 - loss: 0.2799
# Accuracy2: 95.37%
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9594 - loss: 0.2887
# Accuracy3: 95.53%

# %%
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)

thresholds = np.arange(0, 1.01, 0.01) 
best_threshold_1 = 0.0
best_threshold_2 = 0.0
best_threshold_3 = 0.0

best_f1 = 0.0

for threshold in thresholds:
  y_pred_classes = (y_pred1 >= threshold).astype(int)
  f1 = f1_score(y_test, y_pred_classes)
  if f1 > best_f1:
    best_f1 = f1
    best_threshold_1 = threshold
print(f'F1-score1: {best_f1:.4f}')
print('best threshold: ', best_threshold_1)
y_pred1 = (y_pred1 > best_threshold_1).astype(int)

best_threshold = 0.0
best_f1 = 0.0

for threshold in thresholds:
  y_pred_classes = (y_pred2 >= threshold).astype(int)
  f1 = f1_score(y_test, y_pred_classes)
  if f1 > best_f1:
    best_f1 = f1
    best_threshold_2 = threshold
print(f'F1-score2: {best_f1:.4f}')
print('best threshold: ', best_threshold_2)
y_pred2 = (y_pred2 > best_threshold_2).astype(int)

best_threshold = 0.0
best_f1 = 0.0

for threshold in thresholds:
  y_pred_classes = (y_pred3 >= threshold).astype(int)
  f1 = f1_score(y_test, y_pred_classes)
  if f1 > best_f1:
    best_f1 = f1
    best_threshold_3 = threshold
print(f'F1-score3: {best_f1:.4f}')
print('best threshold: ', best_threshold_3)
y_pred3 = (y_pred3 > best_threshold_3).astype(int)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# F1-score1: 0.9504
# best threshold:  0.44
# F1-score2: 0.9488
# best threshold:  0.56
# F1-score3: 0.9506
# best threshold:  0.16

# %%
def print_metrics(y_test, y_pred, model_number):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"Model {model_number} - Metrics:")
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

# %%
import math
def fuzzy_rank(CF, top):
    R_L = np.zeros(CF.shape)
    for i in range(CF.shape[0]):
        for j in range(CF.shape[1]):
            for k in range(CF.shape[2]):
                R_L[i][j][k] = 1 - math.exp(-math.exp(-2.0 * CF[i][j][k])) 
    
    K_L = 0.632 * np.ones(shape=R_L.shape) 
    for i in range(R_L.shape[0]):
        for sample in range(R_L.shape[1]):
            for k in range(top):
                a = R_L[i][sample]
                idx = np.where(a == np.partition(a, k)[k])
                K_L[i][sample][idx] = R_L[i][sample][idx]

    return K_L

def CFS_func(CF, K_L):
    H = CF.shape[0]  # Số lượng bộ phân loại
    for f in range(CF.shape[0]):
        for i in range(CF.shape[1]):
            idx = np.where(K_L[f][i] == 0.632)
            CF[f][i][idx] = 0
    CFS = 1 - np.sum(CF, axis=0) / H
    return CFS

def Gompertz(top=2, *argv):
    L = len(argv)  # Số lượng bộ phân loại
    num_classes = argv[0].shape[1]
    CF = np.zeros(shape=(L, argv[0].shape[0], num_classes))

    for i, arg in enumerate(argv):
        CF[i] = arg

    R_L = fuzzy_rank(CF, top) 
    RS = np.sum(R_L, axis=0)
    CFS = CFS_func(CF, R_L)
    FS = RS * CFS

    predictions = np.argmin(FS, axis=1)
    return predictions
    
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)

y_pred1 = np.hstack((1 - y_pred1, y_pred1))  
y_pred2 = np.hstack((1 - y_pred2, y_pred2))
y_pred3 = np.hstack((1 - y_pred3, y_pred3))

print(y_pred1.shape) 
print(y_pred2.shape) 
print(y_pred3.shape)  
final_predictions = Gompertz(2, y_pred1, y_pred2, y_pred3)
print_metrics(y_test, final_predictions, 'Ensemble with Gompertz')
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# (1881, 2)
# (1881, 2)
# (1881, 2)
# Model Ensemble with Gompertz - Metrics:
# Accuracy: 95.80%
# Precision: 0.9578
# Recall: 0.9476
# F1 Score: 0.9527
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96      1042
#          1.0       0.96      0.95      0.95       839
#
#     accuracy                           0.96      1881
#    macro avg       0.96      0.96      0.96      1881
# weighted avg       0.96      0.96      0.96      1881

# %%
import json
import joblib
from tensorflow.keras.models import save_model   # hoặc model.save()

# ────────────────────────────────────────────────
# 1. Tạo thư mục lưu
# ────────────────────────────────────────────────
SAVE_DIR = "/kaggle/working/saved_models"
os.makedirs(SAVE_DIR, exist_ok=True)

joblib.dump(pca_model,  os.path.join(SAVE_DIR, "pca_model.joblib"))

# ────────────────────────────────────────────────
# 3. Lưu 3 mô hình CNN (dạng Keras native format - khuyến nghị)
# ────────────────────────────────────────────────
model1.save(os.path.join(SAVE_DIR, "cnn_model_32filters.keras"))
model2.save(os.path.join(SAVE_DIR, "cnn_model_64filters.keras"))
model3.save(os.path.join(SAVE_DIR, "cnn_model_48filters.keras"))

print("Đã lưu 3 mô hình CNN (.keras format)")

# model1.save(os.path.join(SAVE_DIR, "cnn_model_32filters.h5"))
# model2.save(os.path.join(SAVE_DIR, "cnn_model_64filters.h5"))
# model3.save(os.path.join(SAVE_DIR, "cnn_model_48filters.h5"))

# ────────────────────────────────────────────────
# 4. Lưu metadata quan trọng (dùng để tái tạo inference chính xác)
# ────────────────────────────────────────────────
metadata = {
    "n_components": n_components,
    "image_size": (224, 224),
    "normalize_mean": [0.485, 0.456, 0.406],
    "normalize_std":  [0.229, 0.224, 0.225],
    "models": {
        "model1": {"filters_first": 32, "file": "cnn_model_32filters.keras"},
        "model2": {"filters_first": 64, "file": "cnn_model_64filters.keras"},
        "model3": {"filters_first": 48, "file": "cnn_model_48filters.keras"}
    },
    "best_thresholds": {
        # Bạn cần lưu lại best_threshold của từng mô hình sau khi tìm ở phần grid search
        "model1": best_threshold_1,   # thay bằng giá trị thật bạn tìm được
        "model2": best_threshold_2,
        "model3": best_threshold_3
    },
    "ensemble": {
        "method": "Gompertz",
        "top": 2
    },
    "classes": sorted(set(data['Class'])),  # hoặc list các class bạn có
    "date_trained": "2025-03"
}

with open(os.path.join(SAVE_DIR, "metadata.json"), "w", encoding="utf-8") as f:
    json.dump(metadata, f, indent=2, ensure_ascii=False)

print("Đã lưu metadata.json")
print("Tất cả mô hình đã được lưu vào:", SAVE_DIR)
# Out:
# Đã lưu 3 mô hình CNN (.keras format)
# Đã lưu metadata.json
# Tất cả mô hình đã được lưu vào: /kaggle/working/saved_models
